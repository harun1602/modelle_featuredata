# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from pyod.models.ae1svm import AE1SVM

# daten laden
normal_path = "features/S01/1/Normal/c_data"
relay_path  = "features/S01/1/Relay/c_data"

with h5py.File("datasets/features_S01_combined.h5", "r") as f:
    normal_group = f[normal_path]
    relay_group  = f[relay_path]

    n_norm = normal_group["0"].shape[0]
    n_relay = relay_group["0"].shape[0]

    dataset_normal = np.zeros((49997, n_norm))
    dataset_relay  = np.zeros((49998, n_relay))

    for i in range(49997):
        try:
            dataset_normal[i] = normal_group[str(i)][:]
        except KeyError:
            continue

    for i in range(49998):
        try:
            dataset_relay[i] = relay_group[str(i)][:]
        except KeyError:
            continue

# daten definieren und skalieren
scaler = StandardScaler()

X_train               = dataset_normal[:47500]
X_test_normal         = dataset_normal[47500:]
X_test_relay          = dataset_relay[47500:]

scaler.fit(X_train)
X_train_scaled        = scaler.transform(X_train)
X_test_norm_scaled    = scaler.transform(X_test_normal)
X_test_relay_scaled   = scaler.transform(X_test_relay)

X_test_combined = np.vstack((X_test_normal, X_test_relay))
X_test_combined_scaled = np.vstack((X_test_norm_scaled, X_test_relay_scaled))

y_true = np.array([0] * len(X_test_normal) + [1] * len(X_test_relay))

# modell trainieren, contamination gibt an, wie viele outlier man im trainigsdatensatz hat
# contamination kann man bei reiner novelty detection zb auf 0.01 oder 0.05 setzen
for n in {(64,32), (128,64), (256,128)}:
    for i in {0.05, 0.1, 0.2}:
        for d in {0.05, 0.1, 0.2}:
            clf = AE1SVM(contamination=0.01, hidden_neurons=n, nu=i, dropout_rate=d)
            clf.fit(X_train)

            # pyod.predict: 0 = inlier, 1 = outlier
            y_pred = clf.predict(X_test_combined)

            # cm und report
            cm = confusion_matrix(y_true, y_pred, labels=[1,0])
            print(f"hidden neurons {n}")
            print(f"nu {i}")
            print(f"dropout rate {d}")
            print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=["Normal","Relay"]))

            # plot
            plt.figure(figsize=(6,5))
            sns.heatmap(cm, annot=True, fmt="d",
                        xticklabels=["Relay","Normal"],
                        yticklabels=["Relay","Normal"],
                        cbar=False)
            plt.xlabel("Predicted")
            plt.ylabel("True")
            plt.title("Konfusionsmatrix")
            plt.tight_layout()
            plt.show()
# Out:
# Epoch 10/50, Loss: 0.6326254910491532
# Epoch 20/50, Loss: 0.5971477014448506
# Epoch 30/50, Loss: 0.5846926191439131
# Epoch 40/50, Loss: 0.5789796866752484
# Epoch 50/50, Loss: 0.5755591103725561
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6590710299384313
# Epoch 20/50, Loss: 0.6215377378343332
# Epoch 30/50, Loss: 0.6136564945331727
# Epoch 40/50, Loss: 0.609764700285112
# Epoch 50/50, Loss: 0.6076462178920656
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.76      0.60      0.53      4995
# weighted avg       0.76      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6887367322388723
# Epoch 20/50, Loss: 0.6590175220460602
# Epoch 30/50, Loss: 0.6510474476147983
# Epoch 40/50, Loss: 0.6476878960525949
# Epoch 50/50, Loss: 0.6460224523086741
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6352088050609486
# Epoch 20/50, Loss: 0.5963692714268912
# Epoch 30/50, Loss: 0.5818924561293438
# Epoch 40/50, Loss: 0.5779677409716327
# Epoch 50/50, Loss: 0.5758161055319237
# hidden neurons (64, 32)
# nu 0.1
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6655378895175176
# Epoch 20/50, Loss: 0.625371097595202
# Epoch 30/50, Loss: 0.6146471356904065
# Epoch 40/50, Loss: 0.609645241539085
# Epoch 50/50, Loss: 0.6047418945164793
# hidden neurons (64, 32)
# nu 0.1
# dropout rate 0.1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.7629788816777945
# Epoch 20/50, Loss: 0.668577143881056
# Epoch 30/50, Loss: 0.6552398250359879
# Epoch 40/50, Loss: 0.6508597229265605
# Epoch 50/50, Loss: 0.6487677546663316
# hidden neurons (64, 32)
# nu 0.1
# dropout rate 0.2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.36      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6346438320598217
# Epoch 20/50, Loss: 0.5959438314943603
# Epoch 30/50, Loss: 0.583684560666582
# Epoch 40/50, Loss: 0.5783896200383953
# Epoch 50/50, Loss: 0.5755319001498046
# hidden neurons (64, 32)
# nu 0.2
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6638831947789048
# Epoch 20/50, Loss: 0.6237822094348946
# Epoch 30/50, Loss: 0.6126318280343657
# Epoch 40/50, Loss: 0.6085446263001824
# Epoch 50/50, Loss: 0.6061226433575756
# hidden neurons (64, 32)
# nu 0.2
# dropout rate 0.1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.76      0.60      0.53      4995
# weighted avg       0.76      0.60      0.53      4995
# Epoch 10/50, Loss: 0.7249928847707884
# Epoch 20/50, Loss: 0.6669261582371362
# Epoch 30/50, Loss: 0.6528358920254691
# Epoch 40/50, Loss: 0.6496185442213258
# Epoch 50/50, Loss: 0.6477623601353129
# hidden neurons (64, 32)
# nu 0.2
# dropout rate 0.2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6050858521100246
# Epoch 20/50, Loss: 0.5685904974889273
# Epoch 30/50, Loss: 0.5571044878526168
# Epoch 40/50, Loss: 0.5495108028453608
# Epoch 50/50, Loss: 0.5452292376696461
# hidden neurons (128, 64)
# nu 0.05
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6225272020908317
# Epoch 20/50, Loss: 0.5878372462911637
# Epoch 30/50, Loss: 0.5784157365058809
# Epoch 40/50, Loss: 0.5740036580297682
# Epoch 50/50, Loss: 0.5702144162221389
# hidden neurons (128, 64)
# nu 0.05
# dropout rate 0.1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6594213151570523
# Epoch 20/50, Loss: 0.6284126728672772
# Epoch 30/50, Loss: 0.6169238167780416
# Epoch 40/50, Loss: 0.6122155849580412
# Epoch 50/50, Loss: 0.610610610748381
# hidden neurons (128, 64)
# nu 0.05
# dropout rate 0.2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.601751817035354
# Epoch 20/50, Loss: 0.5660429250511657
# Epoch 30/50, Loss: 0.5567834384513624
# Epoch 40/50, Loss: 0.5510172303477522
# Epoch 50/50, Loss: 0.5475077633303825
# hidden neurons (128, 64)
# nu 0.1
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6279069810001938
# Epoch 20/50, Loss: 0.5966026262803511
# Epoch 30/50, Loss: 0.5813876671622498
# Epoch 40/50, Loss: 0.574890533360568
# Epoch 50/50, Loss: 0.5715611602722194
# hidden neurons (128, 64)
# nu 0.1
# dropout rate 0.1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.7392328840313536
# Epoch 20/50, Loss: 0.6429948936809193
# Epoch 30/50, Loss: 0.6227186131959009
# Epoch 40/50, Loss: 0.6154644878023
# Epoch 50/50, Loss: 0.6116859780016171
# hidden neurons (128, 64)
# nu 0.1
# dropout rate 0.2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6101818714679692
# Epoch 20/50, Loss: 0.5692412244350421
# Epoch 30/50, Loss: 0.5553017049325436
# Epoch 40/50, Loss: 0.5491694908952873
# Epoch 50/50, Loss: 0.5462602364294457
# hidden neurons (128, 64)
# nu 0.2
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6369766913680517
# Epoch 20/50, Loss: 0.5906002579514025
# Epoch 30/50, Loss: 0.5778050459996619
# Epoch 40/50, Loss: 0.5734569266990379
# Epoch 50/50, Loss: 0.570713609436947
# hidden neurons (128, 64)
# nu 0.2
# dropout rate 0.1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6679540298001132
# Epoch 20/50, Loss: 0.6284893133624234
# Epoch 30/50, Loss: 0.617116079446844
# Epoch 40/50, Loss: 0.6130668596787886
# Epoch 50/50, Loss: 0.6107427214933967
# hidden neurons (128, 64)
# nu 0.2
# dropout rate 0.2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 59
#      57 for d in {0.05, 0.1, 0.2}:
#      58     clf = AE1SVM(contamination=0.01, hidden_neurons=n, nu=i, dropout_rate=d)
# ---> 59     clf.fit(X_train)
#      61     # pyod.predict: 0 = inlier, 1 = outlier
#      62     y_pred = clf.predict(X_test_combined)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyod/models/ae1svm.py:299, in AE1SVM.fit(self, X, y)
#     291 self.model = InnerAE1SVM(n_features=n_features, encoding_dim=32,
#     292                          rff_dim=self.kernel_approx_features,
#     293                          sigma=self.sigma,
#    (...)
#     296                          batch_norm=self.batch_norm,
#     297                          hidden_activation=self.hidden_activation)
#     298 self.model = self.model.to(self.device)
# --> 299 self._train_autoencoder(train_loader)
#     301 if self.best_model_dict is not None:
#     302     self.model.load_state_dict(self.best_model_dict)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyod/models/ae1svm.py:339, in AE1SVM._train_autoencoder(self, train_loader)
#     337     self.model.zero_grad()
#     338     loss.backward()
# --> 339     optimizer.step()
#     340     overall_loss.append(loss.item())
#     341 if (epoch + 1) % 10 == 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:244, in Adam.step(self, closure)
#     232     beta1, beta2 = group["betas"]
#     234     has_complex = self._init_group(
#     235         group,
#     236         params_with_grad,
#    (...)
#     241         state_steps,
#     242     )
# --> 244     adam(
#     245         params_with_grad,
#     246         grads,
#     247         exp_avgs,
#     248         exp_avg_sqs,
#     249         max_exp_avg_sqs,
#     250         state_steps,
#     251         amsgrad=group["amsgrad"],
#     252         has_complex=has_complex,
#     253         beta1=beta1,
#     254         beta2=beta2,
#     255         lr=group["lr"],
#     256         weight_decay=group["weight_decay"],
#     257         eps=group["eps"],
#     258         maximize=group["maximize"],
#     259         foreach=group["foreach"],
#     260         capturable=group["capturable"],
#     261         differentiable=group["differentiable"],
#     262         fused=group["fused"],
#     263         grad_scale=getattr(self, "grad_scale", None),
#     264         found_inf=getattr(self, "found_inf", None),
#     265     )
#     267 return loss
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:876, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     873 else:
#     874     func = _single_tensor_adam
# --> 876 func(
#     877     params,
#     878     grads,
#     879     exp_avgs,
#     880     exp_avg_sqs,
#     881     max_exp_avg_sqs,
#     882     state_steps,
#     883     amsgrad=amsgrad,
#     884     has_complex=has_complex,
#     885     beta1=beta1,
#     886     beta2=beta2,
#     887     lr=lr,
#     888     weight_decay=weight_decay,
#     889     eps=eps,
#     890     maximize=maximize,
#     891     capturable=capturable,
#     892     differentiable=differentiable,
#     893     grad_scale=grad_scale,
#     894     found_inf=found_inf,
#     895 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:478, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     475     else:
#     476         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 478     param.addcdiv_(exp_avg, denom, value=-step_size)
#     480 # Lastly, switch back to complex view
#     481 if amsgrad and torch.is_complex(params[i]):
#
# KeyboardInterrupt:

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from pyod.models.ae1svm import AE1SVM

# daten laden
normal_path = "features/S01/1/Normal/c_data"
relay_path  = "features/S01/1/Relay/c_data"

with h5py.File("datasets/features_S01_combined.h5", "r") as f:
    normal_group = f[normal_path]
    relay_group  = f[relay_path]

    n_norm = normal_group["0"].shape[0]
    n_relay = relay_group["0"].shape[0]

    dataset_normal = np.zeros((49997, n_norm))
    dataset_relay  = np.zeros((49998, n_relay))

    for i in range(49997):
        try:
            dataset_normal[i] = normal_group[str(i)][:]
        except KeyError:
            continue

    for i in range(49998):
        try:
            dataset_relay[i] = relay_group[str(i)][:]
        except KeyError:
            continue

# daten definieren und skalieren
scaler = StandardScaler()

X_train               = dataset_normal[:47500]
X_test_normal         = dataset_normal[47500:]
X_test_relay          = dataset_relay[47500:]

scaler.fit(X_train)
X_train_scaled        = scaler.transform(X_train)
X_test_norm_scaled    = scaler.transform(X_test_normal)
X_test_relay_scaled   = scaler.transform(X_test_relay)

X_test_combined = np.vstack((X_test_normal, X_test_relay))
X_test_combined_scaled = np.vstack((X_test_norm_scaled, X_test_relay_scaled))

y_true = np.array([0] * len(X_test_normal) + [1] * len(X_test_relay))

# modell trainieren, contamination gibt an, wie viele outlier man im trainigsdatensatz hat
# contamination kann man bei reiner novelty detection zb auf 0.01 oder 0.05 setzen
for n in {(64,32), (128,64), (256,128)}:
    for i in {0.05, 0.1, 0.2}:
        for d in {0.05, 0.1, 0.2}:
            clf = AE1SVM(contamination=0.01, hidden_neurons=n, nu=i, dropout_rate=d)
            clf.fit(X_train_scaled)

            # pyod.predict: 0 = inlier, 1 = outlier
            y_pred = clf.predict(X_test_combined_scaled)

            # cm und report
            cm = confusion_matrix(y_true, y_pred, labels=[1,0])
            print(f"hidden neurons {n}")
            print(f"nu {i}")
            print(f"dropout rate {d}")
            print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=["Normal","Relay"]))

            # plot
            plt.figure(figsize=(6,5))
            sns.heatmap(cm, annot=True, fmt="d",
                        xticklabels=["Relay","Normal"],
                        yticklabels=["Relay","Normal"],
                        cbar=False)
            plt.xlabel("Predicted")
            plt.ylabel("True")
            plt.title("Konfusionsmatrix")
            plt.tight_layout()
            plt.show()
# Out:
# Epoch 10/50, Loss: 0.6293452537621713
# Epoch 20/50, Loss: 0.5948287515527872
# Epoch 30/50, Loss: 0.5853879836873976
# Epoch 40/50, Loss: 0.5803251991769681
# Epoch 50/50, Loss: 0.5777441943936075
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.76      0.60      0.53      4995
# weighted avg       0.76      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6482469671904438
# Epoch 20/50, Loss: 0.6197589223031644
# Epoch 30/50, Loss: 0.6133188232227608
# Epoch 40/50, Loss: 0.6074864358612986
# Epoch 50/50, Loss: 0.6050014300980552
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6887250573948176
# Epoch 20/50, Loss: 0.6571820873604077
# Epoch 30/50, Loss: 0.6511959285246403
# Epoch 40/50, Loss: 0.6484105243626669
# Epoch 50/50, Loss: 0.6462844462105722
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6316331402821974
# Epoch 20/50, Loss: 0.5947446204997875
# Epoch 30/50, Loss: 0.5845713659769758
# Epoch 40/50, Loss: 0.5804409117811056
# Epoch 50/50, Loss: 0.5759783845758598
# hidden neurons (64, 32)
# nu 0.1
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.76      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6768021877365883
# Epoch 20/50, Loss: 0.6253720210056112
# Epoch 30/50, Loss: 0.6134378159688378
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 59
#      57 for d in {0.05, 0.1, 0.2}:
#      58     clf = AE1SVM(contamination=0.01, hidden_neurons=n, nu=i, dropout_rate=d)
# ---> 59     clf.fit(X_train_scaled)
#      61     # pyod.predict: 0 = inlier, 1 = outlier
#      62     y_pred = clf.predict(X_test_combined_scaled)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyod/models/ae1svm.py:299, in AE1SVM.fit(self, X, y)
#     291 self.model = InnerAE1SVM(n_features=n_features, encoding_dim=32,
#     292                          rff_dim=self.kernel_approx_features,
#     293                          sigma=self.sigma,
#    (...)
#     296                          batch_norm=self.batch_norm,
#     297                          hidden_activation=self.hidden_activation)
#     298 self.model = self.model.to(self.device)
# --> 299 self._train_autoencoder(train_loader)
#     301 if self.best_model_dict is not None:
#     302     self.model.load_state_dict(self.best_model_dict)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyod/models/ae1svm.py:331, in AE1SVM._train_autoencoder(self, train_loader)
#     329 for data, data_idx in train_loader:
#     330     data = data.to(self.device).float()
# --> 331     reconstructions, rff_features = self.model(data)
#     332     recon_loss = self.loss_fn(data, reconstructions)
#     333     svm_scores = self.model.svm_decision_function(rff_features)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyod/models/ae1svm.py:119, in InnerAE1SVM.forward(self, x)
#     106 def forward(self, x):
#     107     """Forward pass through the model.
#     108
#     109     Parameters
#    (...)
#     117         Reconstructed input and random Fourier features.
#     118     """
# --> 119     x = self.encoder(x)
#     120     rff_features = self.rff(x)
#     121     x = self.decoder(x)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193, in _BatchNorm.forward(self, input)
#     186     bn_training = (self.running_mean is None) and (self.running_var is None)
#     188 r"""
#     189 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     190 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     191 used for normalization (i.e. in eval mode when buffers are not None).
#     192 """
# --> 193 return F.batch_norm(
#     194     input,
#     195     # If buffers are not to be tracked, ensure that they won't be updated
#     196     self.running_mean
#     197     if not self.training or self.track_running_stats
#     198     else None,
#     199     self.running_var if not self.training or self.track_running_stats else None,
#     200     self.weight,
#     201     self.bias,
#     202     bn_training,
#     203     exponential_average_factor,
#     204     self.eps,
#     205 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/functional.py:2822, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2819 if training:
#    2820     _verify_batch_size(input.size())
# -> 2822 return torch.batch_norm(
#    2823     input,
#    2824     weight,
#    2825     bias,
#    2826     running_mean,
#    2827     running_var,
#    2828     training,
#    2829     momentum,
#    2830     eps,
#    2831     torch.backends.cudnn.enabled,
#    2832 )
#
# KeyboardInterrupt:

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler
from pyod.models.ae1svm import AE1SVM

# daten laden
normal_path = "features/S01/1/Normal/c_data"
relay_path  = "features/S01/1/Relay/c_data"

with h5py.File("datasets/features_S01_combined.h5", "r") as f:
    normal_group = f[normal_path]
    relay_group  = f[relay_path]

    n_norm = normal_group["0"].shape[0]
    n_relay = relay_group["0"].shape[0]

    dataset_normal = np.zeros((49997, n_norm))
    dataset_relay  = np.zeros((49998, n_relay))

    for i in range(49997):
        try:
            dataset_normal[i] = normal_group[str(i)][:]
        except KeyError:
            continue

    for i in range(49998):
        try:
            dataset_relay[i] = relay_group[str(i)][:]
        except KeyError:
            continue

# daten definieren und skalieren
scaler = MinMaxScaler()

X_train               = dataset_normal[:47500]
X_test_normal         = dataset_normal[47500:]
X_test_relay          = dataset_relay[47500:]

scaler.fit(X_train)
X_train_scaled        = scaler.transform(X_train)
X_test_norm_scaled    = scaler.transform(X_test_normal)
X_test_relay_scaled   = scaler.transform(X_test_relay)

X_test_combined = np.vstack((X_test_normal, X_test_relay))
X_test_combined_scaled = np.vstack((X_test_norm_scaled, X_test_relay_scaled))

y_true = np.array([0] * len(X_test_normal) + [1] * len(X_test_relay))

# modell trainieren, contamination gibt an, wie viele outlier man im trainigsdatensatz hat
# contamination kann man bei reiner novelty detection zb auf 0.01 oder 0.05 setzen
for n in {(64,32), (128,64), (256,128)}:
    for i in {0.05, 0.1, 0.2}:
        for d in {0.05, 0.1, 0.2}:
            clf = AE1SVM(contamination=0.01, hidden_neurons=n, nu=i, dropout_rate=d)
            clf.fit(X_train_scaled)

            # pyod.predict: 0 = inlier, 1 = outlier
            y_pred = clf.predict(X_test_combined_scaled)

            # cm und report
            cm = confusion_matrix(y_true, y_pred, labels=[1,0])
            print(f"hidden neurons {n}")
            print(f"nu {i}")
            print(f"dropout rate {d}")
            print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=["Normal","Relay"]))

            # plot
            plt.figure(figsize=(6,5))
            sns.heatmap(cm, annot=True, fmt="d",
                        xticklabels=["Relay","Normal"],
                        yticklabels=["Relay","Normal"],
                        cbar=False)
            plt.xlabel("Predicted")
            plt.ylabel("True")
            plt.title("Konfusionsmatrix")
            plt.tight_layout()
            plt.show()
# Out:
# Epoch 10/50, Loss: 0.6254185219204386
# Epoch 20/50, Loss: 0.5941765482778902
# Epoch 30/50, Loss: 0.5840266219694606
# Epoch 40/50, Loss: 0.5792140770640839
# Epoch 50/50, Loss: 0.5762907775363537
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6648173904178118
# Epoch 20/50, Loss: 0.6240120170293031
# Epoch 30/50, Loss: 0.6147337167150645
# Epoch 40/50, Loss: 0.6094835576987025
# Epoch 50/50, Loss: 0.6064713727745544
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.1
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.7072202058151514
# Epoch 20/50, Loss: 0.6645446438982029
# Epoch 30/50, Loss: 0.6540099055277379
# Epoch 40/50, Loss: 0.6503846315221754
# Epoch 50/50, Loss: 0.6479602321831867
# hidden neurons (64, 32)
# nu 0.05
# dropout rate 0.2
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.22      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.629574779207859
# Epoch 20/50, Loss: 0.5962235496702419
# Epoch 30/50, Loss: 0.5867451070535062
# Epoch 40/50, Loss: 0.5812627153966563
# Epoch 50/50, Loss: 0.5782704926299728
# hidden neurons (64, 32)
# nu 0.1
# dropout rate 0.05
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.56      0.99      0.71      2497
#        Relay       0.95      0.21      0.35      2498
#
#     accuracy                           0.60      4995
#    macro avg       0.75      0.60      0.53      4995
# weighted avg       0.75      0.60      0.53      4995
# Epoch 10/50, Loss: 0.6603311373729899
# Epoch 20/50, Loss: 0.6220005079752668
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 59
#      57 for d in {0.05, 0.1, 0.2}:
#      58     clf = AE1SVM(contamination=0.01, hidden_neurons=n, nu=i, dropout_rate=d)
# ---> 59     clf.fit(X_train_scaled)
#      61     # pyod.predict: 0 = inlier, 1 = outlier
#      62     y_pred = clf.predict(X_test_combined_scaled)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyod/models/ae1svm.py:299, in AE1SVM.fit(self, X, y)
#     291 self.model = InnerAE1SVM(n_features=n_features, encoding_dim=32,
#     292                          rff_dim=self.kernel_approx_features,
#     293                          sigma=self.sigma,
#    (...)
#     296                          batch_norm=self.batch_norm,
#     297                          hidden_activation=self.hidden_activation)
#     298 self.model = self.model.to(self.device)
# --> 299 self._train_autoencoder(train_loader)
#     301 if self.best_model_dict is not None:
#     302     self.model.load_state_dict(self.best_model_dict)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyod/models/ae1svm.py:331, in AE1SVM._train_autoencoder(self, train_loader)
#     329 for data, data_idx in train_loader:
#     330     data = data.to(self.device).float()
# --> 331     reconstructions, rff_features = self.model(data)
#     332     recon_loss = self.loss_fn(data, reconstructions)
#     333     svm_scores = self.model.svm_decision_function(rff_features)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyod/models/ae1svm.py:121, in InnerAE1SVM.forward(self, x)
#     119 x = self.encoder(x)
#     120 rff_features = self.rff(x)
# --> 121 x = self.decoder(x)
#     122 return x, rff_features
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/dropout.py:70, in Dropout.forward(self, input)
#      69 def forward(self, input: Tensor) -> Tensor:
# ---> 70     return F.dropout(input, self.p, self.training, self.inplace)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/functional.py:1425, in dropout(input, p, training, inplace)
#    1422 if p < 0.0 or p > 1.0:
#    1423     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
#    1424 return (
# -> 1425     _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#    1426 )
#
# KeyboardInterrupt:
